# %% [markdown]
# ## <div align="center"> TUGAS LAB IS794 DEEP LEARNING </div>
# ### <div align="center"> WEEK [11] : [Deep Learning for Timeseries Data] </div>
#
# #### <div align="center"> Semester Ganjil 2023/2024 </div>

# %%
from numpy.ma import outerproduct
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import SimpleRNN, Dense

# %%
# Load the stock price dataset
df = pd.read_csv('BBCA.JK.csv')

output = df['Adj Close'].values.reshape(-1, 1)
features = ['Open', 'High', 'Low', 'Volume']

# %%
#Scaling
scaler = MinMaxScaler(feature_range=(0,1))
feature_transform = scaler.fit_transform(df[features])
feature_transform= pd.DataFrame(columns=features, data=feature_transform, index=df.index)
scaled_output = scaler.fit_transform(output)
feature_transform.head()
# Out:
#        Open      High       Low    Volume
# 0  0.958333  0.956522  0.962963  0.282898
# 1  0.916667  1.000000  0.962963  0.507473
# 2  0.875000  0.826087  0.851852  0.457543
# 3  0.750000  0.956522  0.814815  0.388941
# 4  1.000000  0.956522  1.000000  0.372331

# %%
from sklearn.model_selection import TimeSeriesSplit
from sklearn.metrics import mean_absolute_error

#Splitting to Training set and Test set
timesplit= TimeSeriesSplit(n_splits=3) #split into training, validation, and testing set
for train_index, test_index in timesplit.split(feature_transform):
    X_train, X_test = feature_transform[:len(train_index)], feature_transform[len (train_index): (len(train_index)+len(test_index))]
    y_train, y_test = scaled_output[:len(train_index)], scaled_output[len(train_index): (len(train_index)+len(test_index))]
    
    split_index = int(len(train_index)*0.8) #80% as training and 20% as validation.
    X_train, X_val = X_train[:split_index], X_train[split_index:]
    y_train, y_val = y_train[:split_index], y_train[split_index:]

#Process the data for the model
trainX = np.array(X_train)
valX = np.array(X_val)
testX = np.array(X_test)
X_train = trainX.reshape(X_train.shape[0], 1, X_train.shape[1])
X_val = valX.reshape(X_val.shape[0], 1, X_val.shape[1])
X_test = testX.reshape(X_test.shape[0], 1, X_test.shape[1])

# %%
#Building the SimpleRNN Model
model = Sequential()
model.add(SimpleRNN(units=50, activation='relu', input_shape=(1, len(features))))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mean_squared_error')

#Train the model
model.fit(X_train, y_train, epochs=50, batch_size=32, validation_data=(X_val, y_val))

#Model Prediction
y_pred = model.predict(X_test)

mae = mean_absolute_error(y_test, y_pred)
print (f'Mean Absolute Error (MAE): {mae:.4f}')
# Out:
# Epoch 1/50
# 2/2 [==============================] - 1s 245ms/step - loss: 0.2290 - val_loss: 0.0749
# Epoch 2/50
# 2/2 [==============================] - 0s 45ms/step - loss: 0.1853 - val_loss: 0.0588
# Epoch 3/50
# 2/2 [==============================] - 0s 39ms/step - loss: 0.1461 - val_loss: 0.0449
# Epoch 4/50
# 2/2 [==============================] - 0s 26ms/step - loss: 0.1139 - val_loss: 0.0334
# Epoch 5/50
# 2/2 [==============================] - 0s 33ms/step - loss: 0.0853 - val_loss: 0.0243
# Epoch 6/50
# 2/2 [==============================] - 0s 39ms/step - loss: 0.0619 - val_loss: 0.0173
# Epoch 7/50
# 2/2 [==============================] - 0s 31ms/step - loss: 0.0439 - val_loss: 0.0124
# Epoch 8/50
# 2/2 [==============================] - 0s 30ms/step - loss: 0.0297 - val_loss: 0.0092
# Epoch 9/50
# 2/2 [==============================] - 0s 33ms/step - loss: 0.0194 - val_loss: 0.0076
# Epoch 10/50
# 2/2 [==============================] - 0s 39ms/step - loss: 0.0124 - val_loss: 0.0070
# Epoch 11/50
# 2/2 [==============================] - 0s 47ms/step - loss: 0.0086 - val_loss: 0.0073
# Epoch 12/50
# 2/2 [==============================] - 0s 41ms/step - loss: 0.0066 - val_loss: 0.0082
# Epoch 13/50
# 2/2 [==============================] - 0s 33ms/step - loss: 0.0061 - val_loss: 0.0092
# Epoch 14/50
# 2/2 [==============================] - 0s 47ms/step - loss: 0.0065 - val_loss: 0.0101
# Epoch 15/50
# 2/2 [==============================] - 0s 42ms/step - loss: 0.0072 - val_loss: 0.0108
# Epoch 16/50
# 2/2 [==============================] - 0s 29ms/step - loss: 0.0079 - val_loss: 0.0113
# Epoch 17/50
# 2/2 [==============================] - 0s 38ms/step - loss: 0.0085 - val_loss: 0.0113
# Epoch 18/50
# 2/2 [==============================] - 0s 34ms/step - loss: 0.0087 - val_loss: 0.0111
# Epoch 19/50
# 2/2 [==============================] - 0s 56ms/step - loss: 0.0085 - val_loss: 0.0106
# Epoch 20/50
# 2/2 [==============================] - 0s 64ms/step - loss: 0.0082 - val_loss: 0.0100
# Epoch 21/50
# 2/2 [==============================] - 0s 57ms/step - loss: 0.0076 - val_loss: 0.0094
# Epoch 22/50
# 2/2 [==============================] - 0s 49ms/step - loss: 0.0070 - val_loss: 0.0088
# Epoch 23/50
# 2/2 [==============================] - 0s 59ms/step - loss: 0.0065 - val_loss: 0.0081
# Epoch 24/50
# 2/2 [==============================] - 0s 45ms/step - loss: 0.0059 - val_loss: 0.0074
# Epoch 25/50
# 2/2 [==============================] - 0s 51ms/step - loss: 0.0055 - val_loss: 0.0068
# Epoch 26/50
# 2/2 [==============================] - 0s 33ms/step - loss: 0.0050 - val_loss: 0.0063
# Epoch 27/50
# 2/2 [==============================] - 0s 69ms/step - loss: 0.0048 - val_loss: 0.0058
# Epoch 28/50
# 2/2 [==============================] - 0s 49ms/step - loss: 0.0045 - val_loss: 0.0054
# Epoch 29/50
# 2/2 [==============================] - 0s 43ms/step - loss: 0.0044 - val_loss: 0.0051
# Epoch 30/50
# 2/2 [==============================] - 0s 41ms/step - loss: 0.0043 - val_loss: 0.0049
# Epoch 31/50
# 2/2 [==============================] - 0s 39ms/step - loss: 0.0042 - val_loss: 0.0047
# Epoch 32/50
# 2/2 [==============================] - 0s 39ms/step - loss: 0.0042 - val_loss: 0.0046
# Epoch 33/50
# 2/2 [==============================] - 0s 42ms/step - loss: 0.0042 - val_loss: 0.0045
# Epoch 34/50
# 2/2 [==============================] - 0s 32ms/step - loss: 0.0041 - val_loss: 0.0044
# Epoch 35/50
# 2/2 [==============================] - 0s 31ms/step - loss: 0.0040 - val_loss: 0.0044
# Epoch 36/50
# 2/2 [==============================] - 0s 36ms/step - loss: 0.0039 - val_loss: 0.0044
# Epoch 37/50
# 2/2 [==============================] - 0s 41ms/step - loss: 0.0038 - val_loss: 0.0045
# Epoch 38/50
# 2/2 [==============================] - 0s 45ms/step - loss: 0.0038 - val_loss: 0.0045
# Epoch 39/50
# 2/2 [==============================] - 0s 45ms/step - loss: 0.0038 - val_loss: 0.0045
# Epoch 40/50
# 2/2 [==============================] - 0s 49ms/step - loss: 0.0037 - val_loss: 0.0045
# Epoch 41/50
# 2/2 [==============================] - 0s 42ms/step - loss: 0.0037 - val_loss: 0.0044
# Epoch 42/50
# 2/2 [==============================] - 0s 30ms/step - loss: 0.0037 - val_loss: 0.0043
# Epoch 43/50
# 2/2 [==============================] - 0s 41ms/step - loss: 0.0037 - val_loss: 0.0042
# Epoch 44/50
# 2/2 [==============================] - 0s 28ms/step - loss: 0.0036 - val_loss: 0.0041
# Epoch 45/50
# 2/2 [==============================] - 0s 33ms/step - loss: 0.0036 - val_loss: 0.0040
# Epoch 46/50
# 2/2 [==============================] - 0s 40ms/step - loss: 0.0035 - val_loss: 0.0038
# Epoch 47/50
# 2/2 [==============================] - 0s 30ms/step - loss: 0.0035 - val_loss: 0.0037
# Epoch 48/50
# 2/2 [==============================] - 0s 32ms/step - loss: 0.0034 - val_loss: 0.0036
# Epoch 49/50
# 2/2 [==============================] - 0s 34ms/step - loss: 0.0034 - val_loss: 0.0035
# Epoch 50/50
# 2/2 [==============================] - 0s 32ms/step - loss: 0.0035 - val_loss: 0.0034
# 1/1 [==============================] - 0s 237ms/step
# Mean Absolute Error (MAE): 0.0790

# %%
#Predicted vs True Adj Close Value - SimpleRNN
plt.plot(y_test, label='True Value')
plt.plot(y_pred, label='Model Value')
plt.title("Prediction by SimpleRNN")
plt.xlabel('Time Scale')
plt.ylabel('Scaled Value')
plt.legend()
plt.show()

# %%
from tensorflow.keras.layers import LSTM

#Building the LSTM Model
lstm = Sequential()
lstm.add(LSTM(50, input_shape=(1, len(features)), activation='relu'))
lstm.add(Dense(1))
lstm.compile(optimizer='adam', loss='mean_squared_error', metrics=['mean_absolute_error'])

# Train the model
lstm.fit(X_train, y_train, epochs=50, batch_size=32, validation_data=(X_val, y_val))

#Model Prediction
y_pred = lstm.predict(X_test)

mae = mean_absolute_error(y_test, y_pred)
print(f'Mean Absolute Error (MAE): {mae:.4f}')
# Out:
# Epoch 1/50
# 2/2 [==============================] - 2s 318ms/step - loss: 0.6549 - mean_absolute_error: 0.7906 - val_loss: 0.2666 - val_mean_absolute_error: 0.4869
# Epoch 2/50
# 2/2 [==============================] - 0s 37ms/step - loss: 0.6387 - mean_absolute_error: 0.7804 - val_loss: 0.2591 - val_mean_absolute_error: 0.4793
# Epoch 3/50
# 2/2 [==============================] - 0s 29ms/step - loss: 0.6227 - mean_absolute_error: 0.7704 - val_loss: 0.2518 - val_mean_absolute_error: 0.4719
# Epoch 4/50
# 2/2 [==============================] - 0s 37ms/step - loss: 0.6075 - mean_absolute_error: 0.7606 - val_loss: 0.2447 - val_mean_absolute_error: 0.4645
# Epoch 5/50
# 2/2 [==============================] - 0s 35ms/step - loss: 0.5928 - mean_absolute_error: 0.7510 - val_loss: 0.2377 - val_mean_absolute_error: 0.4571
# Epoch 6/50
# 2/2 [==============================] - 0s 42ms/step - loss: 0.5786 - mean_absolute_error: 0.7418 - val_loss: 0.2308 - val_mean_absolute_error: 0.4497
# Epoch 7/50
# 2/2 [==============================] - 0s 41ms/step - loss: 0.5646 - mean_absolute_error: 0.7324 - val_loss: 0.2239 - val_mean_absolute_error: 0.4423
# Epoch 8/50
# 2/2 [==============================] - 0s 26ms/step - loss: 0.5505 - mean_absolute_error: 0.7230 - val_loss: 0.2171 - val_mean_absolute_error: 0.4348
# Epoch 9/50
# 2/2 [==============================] - 0s 26ms/step - loss: 0.5366 - mean_absolute_error: 0.7135 - val_loss: 0.2104 - val_mean_absolute_error: 0.4272
# Epoch 10/50
# 2/2 [==============================] - 0s 33ms/step - loss: 0.5227 - mean_absolute_error: 0.7038 - val_loss: 0.2036 - val_mean_absolute_error: 0.4196
# Epoch 11/50
# 2/2 [==============================] - 0s 43ms/step - loss: 0.5084 - mean_absolute_error: 0.6938 - val_loss: 0.1970 - val_mean_absolute_error: 0.4119
# Epoch 12/50
# 2/2 [==============================] - 0s 38ms/step - loss: 0.4942 - mean_absolute_error: 0.6838 - val_loss: 0.1903 - val_mean_absolute_error: 0.4042
# Epoch 13/50
# 2/2 [==============================] - 0s 30ms/step - loss: 0.4802 - mean_absolute_error: 0.6736 - val_loss: 0.1838 - val_mean_absolute_error: 0.3964
# Epoch 14/50
# 2/2 [==============================] - 0s 29ms/step - loss: 0.4658 - mean_absolute_error: 0.6632 - val_loss: 0.1773 - val_mean_absolute_error: 0.3884
# Epoch 15/50
# 2/2 [==============================] - 0s 29ms/step - loss: 0.4518 - mean_absolute_error: 0.6527 - val_loss: 0.1708 - val_mean_absolute_error: 0.3805
# Epoch 16/50
# 2/2 [==============================] - 0s 29ms/step - loss: 0.4372 - mean_absolute_error: 0.6419 - val_loss: 0.1644 - val_mean_absolute_error: 0.3723
# Epoch 17/50
# 2/2 [==============================] - 0s 37ms/step - loss: 0.4227 - mean_absolute_error: 0.6309 - val_loss: 0.1579 - val_mean_absolute_error: 0.3640
# Epoch 18/50
# 2/2 [==============================] - 0s 29ms/step - loss: 0.4084 - mean_absolute_error: 0.6197 - val_loss: 0.1514 - val_mean_absolute_error: 0.3555
# Epoch 19/50
# 2/2 [==============================] - 0s 28ms/step - loss: 0.3941 - mean_absolute_error: 0.6082 - val_loss: 0.1450 - val_mean_absolute_error: 0.3469
# Epoch 20/50
# 2/2 [==============================] - 0s 31ms/step - loss: 0.3792 - mean_absolute_error: 0.5964 - val_loss: 0.1387 - val_mean_absolute_error: 0.3382
# Epoch 21/50
# 2/2 [==============================] - 0s 42ms/step - loss: 0.3648 - mean_absolute_error: 0.5845 - val_loss: 0.1324 - val_mean_absolute_error: 0.3293
# Epoch 22/50
# 2/2 [==============================] - 0s 42ms/step - loss: 0.3504 - mean_absolute_error: 0.5723 - val_loss: 0.1262 - val_mean_absolute_error: 0.3203
# Epoch 23/50
# 2/2 [==============================] - 0s 32ms/step - loss: 0.3357 - mean_absolute_error: 0.5598 - val_loss: 0.1200 - val_mean_absolute_error: 0.3111
# Epoch 24/50
# 2/2 [==============================] - 0s 29ms/step - loss: 0.3215 - mean_absolute_error: 0.5472 - val_loss: 0.1139 - val_mean_absolute_error: 0.3018
# Epoch 25/50
# 2/2 [==============================] - 0s 30ms/step - loss: 0.3069 - mean_absolute_error: 0.5343 - val_loss: 0.1080 - val_mean_absolute_error: 0.2924
# Epoch 26/50
# 2/2 [==============================] - 0s 31ms/step - loss: 0.2929 - mean_absolute_error: 0.5213 - val_loss: 0.1021 - val_mean_absolute_error: 0.2829
# Epoch 27/50
# 2/2 [==============================] - 0s 31ms/step - loss: 0.2782 - mean_absolute_error: 0.5077 - val_loss: 0.0963 - val_mean_absolute_error: 0.2732
# Epoch 28/50
# 2/2 [==============================] - 0s 30ms/step - loss: 0.2642 - mean_absolute_error: 0.4942 - val_loss: 0.0905 - val_mean_absolute_error: 0.2632
# Epoch 29/50
# 2/2 [==============================] - 0s 33ms/step - loss: 0.2501 - mean_absolute_error: 0.4801 - val_loss: 0.0848 - val_mean_absolute_error: 0.2529
# Epoch 30/50
# 2/2 [==============================] - 0s 27ms/step - loss: 0.2361 - mean_absolute_error: 0.4657 - val_loss: 0.0793 - val_mean_absolute_error: 0.2425
# Epoch 31/50
# 2/2 [==============================] - 0s 24ms/step - loss: 0.2218 - mean_absolute_error: 0.4508 - val_loss: 0.0739 - val_mean_absolute_error: 0.2320
# Epoch 32/50
# 2/2 [==============================] - 0s 35ms/step - loss: 0.2082 - mean_absolute_error: 0.4359 - val_loss: 0.0686 - val_mean_absolute_error: 0.2220
# Epoch 33/50
# 2/2 [==============================] - 0s 25ms/step - loss: 0.1946 - mean_absolute_error: 0.4206 - val_loss: 0.0635 - val_mean_absolute_error: 0.2129
# Epoch 34/50
# 2/2 [==============================] - 0s 42ms/step - loss: 0.1810 - mean_absolute_error: 0.4049 - val_loss: 0.0586 - val_mean_absolute_error: 0.2037
# Epoch 35/50
# 2/2 [==============================] - 0s 27ms/step - loss: 0.1680 - mean_absolute_error: 0.3891 - val_loss: 0.0538 - val_mean_absolute_error: 0.1943
# Epoch 36/50
# 2/2 [==============================] - 0s 34ms/step - loss: 0.1552 - mean_absolute_error: 0.3729 - val_loss: 0.0492 - val_mean_absolute_error: 0.1848
# Epoch 37/50
# 2/2 [==============================] - 0s 29ms/step - loss: 0.1427 - mean_absolute_error: 0.3563 - val_loss: 0.0449 - val_mean_absolute_error: 0.1761
# Epoch 38/50
# 2/2 [==============================] - 0s 31ms/step - loss: 0.1306 - mean_absolute_error: 0.3397 - val_loss: 0.0408 - val_mean_absolute_error: 0.1682
# Epoch 39/50
# 2/2 [==============================] - 0s 35ms/step - loss: 0.1188 - mean_absolute_error: 0.3232 - val_loss: 0.0369 - val_mean_absolute_error: 0.1601
# Epoch 40/50
# 2/2 [==============================] - 0s 38ms/step - loss: 0.1074 - mean_absolute_error: 0.3067 - val_loss: 0.0333 - val_mean_absolute_error: 0.1519
# Epoch 41/50
# 2/2 [==============================] - 0s 39ms/step - loss: 0.0970 - mean_absolute_error: 0.2902 - val_loss: 0.0299 - val_mean_absolute_error: 0.1437
# Epoch 42/50
# 2/2 [==============================] - 0s 47ms/step - loss: 0.0865 - mean_absolute_error: 0.2733 - val_loss: 0.0268 - val_mean_absolute_error: 0.1355
# Epoch 43/50
# 2/2 [==============================] - 0s 56ms/step - loss: 0.0770 - mean_absolute_error: 0.2561 - val_loss: 0.0241 - val_mean_absolute_error: 0.1273
# Epoch 44/50
# 2/2 [==============================] - 0s 56ms/step - loss: 0.0680 - mean_absolute_error: 0.2392 - val_loss: 0.0216 - val_mean_absolute_error: 0.1192
# Epoch 45/50
# 2/2 [==============================] - 0s 50ms/step - loss: 0.0597 - mean_absolute_error: 0.2231 - val_loss: 0.0195 - val_mean_absolute_error: 0.1112
# Epoch 46/50
# 2/2 [==============================] - 0s 34ms/step - loss: 0.0522 - mean_absolute_error: 0.2074 - val_loss: 0.0177 - val_mean_absolute_error: 0.1038
# Epoch 47/50
# 2/2 [==============================] - 0s 44ms/step - loss: 0.0453 - mean_absolute_error: 0.1928 - val_loss: 0.0161 - val_mean_absolute_error: 0.0990
# Epoch 48/50
# 2/2 [==============================] - 0s 32ms/step - loss: 0.0394 - mean_absolute_error: 0.1786 - val_loss: 0.0149 - val_mean_absolute_error: 0.0964
# Epoch 49/50
# 2/2 [==============================] - 0s 39ms/step - loss: 0.0339 - mean_absolute_error: 0.1643 - val_loss: 0.0139 - val_mean_absolute_error: 0.0949
# Epoch 50/50
# 2/2 [==============================] - 0s 25ms/step - loss: 0.0292 - mean_absolute_error: 0.1516 - val_loss: 0.0132 - val_mean_absolute_error: 0.0957
# 1/1 [==============================] - 0s 162ms/step
# Mean Absolute Error (MAE): 0.1072

# %%
#Predicted vs True Adj Close Value - LSTM 
plt.plot(y_test, label='True Value')
plt.plot(y_pred, label='Model Value')
plt.title("Prediction by LSTM")
plt.xlabel('Time Scale')
plt.ylabel('Scaled Value')
plt.legend()
plt.show()

# %%
from tensorflow.keras.layers import LSTM
from sklearn.metrics import mean_absolute_error
from keras.layers import Dropout

#Building the LSTM Model
lstm2 = Sequential()
lstm2.add(LSTM(50, input_shape=(1, len(features)), activation='relu'))
lstm2.add(Dropout (0.7))
lstm2.add(Dense (1))
lstm2.compile(optimizer='adam', loss='mean_squared_error')

# Train the model
lstm2.fit(X_train, y_train, epochs=50, batch_size=32, validation_data=(X_val, y_val))

#Model Prediction
y_pred = lstm2.predict(X_test)

mae = mean_absolute_error(y_test, y_pred)
print(f'Mean Absolute Error (MAE): {mae:.4f}')
# Out:
# Epoch 1/50
# 2/2 [==============================] - 1s 223ms/step - loss: 0.6925 - val_loss: 0.2759
# Epoch 2/50
# 2/2 [==============================] - 0s 43ms/step - loss: 0.6815 - val_loss: 0.2657
# Epoch 3/50
# 2/2 [==============================] - 0s 34ms/step - loss: 0.6361 - val_loss: 0.2558
# Epoch 4/50
# 2/2 [==============================] - 0s 36ms/step - loss: 0.6344 - val_loss: 0.2463
# Epoch 5/50
# 2/2 [==============================] - 0s 37ms/step - loss: 0.5895 - val_loss: 0.2371
# Epoch 6/50
# 2/2 [==============================] - 0s 28ms/step - loss: 0.5960 - val_loss: 0.2282
# Epoch 7/50
# 2/2 [==============================] - 0s 28ms/step - loss: 0.5744 - val_loss: 0.2195
# Epoch 8/50
# 2/2 [==============================] - 0s 16ms/step - loss: 0.5670 - val_loss: 0.2109
# Epoch 9/50
# 2/2 [==============================] - 0s 54ms/step - loss: 0.5325 - val_loss: 0.2026
# Epoch 10/50
# 2/2 [==============================] - 0s 34ms/step - loss: 0.5189 - val_loss: 0.1944
# Epoch 11/50
# 2/2 [==============================] - 0s 30ms/step - loss: 0.5039 - val_loss: 0.1865
# Epoch 12/50
# 2/2 [==============================] - 0s 41ms/step - loss: 0.4898 - val_loss: 0.1786
# Epoch 13/50
# 2/2 [==============================] - 0s 26ms/step - loss: 0.4508 - val_loss: 0.1708
# Epoch 14/50
# 2/2 [==============================] - 0s 18ms/step - loss: 0.4408 - val_loss: 0.1631
# Epoch 15/50
# 2/2 [==============================] - 0s 31ms/step - loss: 0.4138 - val_loss: 0.1554
# Epoch 16/50
# 2/2 [==============================] - 0s 31ms/step - loss: 0.4226 - val_loss: 0.1479
# Epoch 17/50
# 2/2 [==============================] - 0s 32ms/step - loss: 0.4000 - val_loss: 0.1405
# Epoch 18/50
# 2/2 [==============================] - 0s 42ms/step - loss: 0.3843 - val_loss: 0.1333
# Epoch 19/50
# 2/2 [==============================] - 0s 39ms/step - loss: 0.3729 - val_loss: 0.1262
# Epoch 20/50
# 2/2 [==============================] - 0s 44ms/step - loss: 0.3606 - val_loss: 0.1193
# Epoch 21/50
# 2/2 [==============================] - 0s 40ms/step - loss: 0.3368 - val_loss: 0.1126
# Epoch 22/50
# 2/2 [==============================] - 0s 45ms/step - loss: 0.3340 - val_loss: 0.1060
# Epoch 23/50
# 2/2 [==============================] - 0s 32ms/step - loss: 0.3020 - val_loss: 0.0996
# Epoch 24/50
# 2/2 [==============================] - 0s 37ms/step - loss: 0.2630 - val_loss: 0.0933
# Epoch 25/50
# 2/2 [==============================] - 0s 40ms/step - loss: 0.2632 - val_loss: 0.0873
# Epoch 26/50
# 2/2 [==============================] - 0s 48ms/step - loss: 0.2762 - val_loss: 0.0815
# Epoch 27/50
# 2/2 [==============================] - 0s 34ms/step - loss: 0.2280 - val_loss: 0.0759
# Epoch 28/50
# 2/2 [==============================] - 0s 37ms/step - loss: 0.2431 - val_loss: 0.0705
# Epoch 29/50
# 2/2 [==============================] - 0s 31ms/step - loss: 0.2431 - val_loss: 0.0654
# Epoch 30/50
# 2/2 [==============================] - 0s 48ms/step - loss: 0.2163 - val_loss: 0.0604
# Epoch 31/50
# 2/2 [==============================] - 0s 37ms/step - loss: 0.1822 - val_loss: 0.0556
# Epoch 32/50
# 2/2 [==============================] - 0s 47ms/step - loss: 0.1615 - val_loss: 0.0511
# Epoch 33/50
# 2/2 [==============================] - 0s 31ms/step - loss: 0.1538 - val_loss: 0.0469
# Epoch 34/50
# 2/2 [==============================] - 0s 31ms/step - loss: 0.1566 - val_loss: 0.0429
# Epoch 35/50
# 2/2 [==============================] - 0s 32ms/step - loss: 0.1766 - val_loss: 0.0391
# Epoch 36/50
# 2/2 [==============================] - 0s 44ms/step - loss: 0.1305 - val_loss: 0.0356
# Epoch 37/50
# 2/2 [==============================] - 0s 34ms/step - loss: 0.1248 - val_loss: 0.0324
# Epoch 38/50
# 2/2 [==============================] - 0s 38ms/step - loss: 0.1273 - val_loss: 0.0296
# Epoch 39/50
# 2/2 [==============================] - 0s 43ms/step - loss: 0.0810 - val_loss: 0.0271
# Epoch 40/50
# 2/2 [==============================] - 0s 38ms/step - loss: 0.1166 - val_loss: 0.0250
# Epoch 41/50
# 2/2 [==============================] - 0s 36ms/step - loss: 0.0889 - val_loss: 0.0231
# Epoch 42/50
# 2/2 [==============================] - 0s 41ms/step - loss: 0.0781 - val_loss: 0.0216
# Epoch 43/50
# 2/2 [==============================] - 0s 35ms/step - loss: 0.0817 - val_loss: 0.0202
# Epoch 44/50
# 2/2 [==============================] - 0s 32ms/step - loss: 0.0471 - val_loss: 0.0191
# Epoch 45/50
# 2/2 [==============================] - 0s 39ms/step - loss: 0.0841 - val_loss: 0.0182
# Epoch 46/50
# 2/2 [==============================] - 0s 35ms/step - loss: 0.0636 - val_loss: 0.0175
# Epoch 47/50
# 2/2 [==============================] - 0s 27ms/step - loss: 0.0850 - val_loss: 0.0169
# Epoch 48/50
# 2/2 [==============================] - 0s 35ms/step - loss: 0.0797 - val_loss: 0.0165
# Epoch 49/50
# 2/2 [==============================] - 0s 42ms/step - loss: 0.0781 - val_loss: 0.0162
# Epoch 50/50
# 2/2 [==============================] - 0s 34ms/step - loss: 0.0625 - val_loss: 0.0159
# 1/1 [==============================] - 0s 160ms/step
# Mean Absolute Error (MAE): 0.1046

# %%
#Predicted vs True Adj Close Value - LSTM
plt.plot(y_test, label='True Value')
plt.plot(y_pred, label='Model Value')
plt.title("Prediction by LSTM")
plt.xlabel('Time Scale')
plt.ylabel('Scaled Value')
plt.legend()
plt.show()

# %%
from tensorflow.keras.layers import LSTM
from sklearn.metrics import mean_absolute_error
from keras.layers import Dropout, Bidirectional

#Building the Bidirectional LSTM Model
lstm3 = Sequential()
lstm3.add(Bidirectional (LSTM(16, input_shape=(1, len (features)), activation='relu')))
lstm3.add(Dense (1))
lstm3.compile(optimizer='adam', loss='mean_squared_error', metrics=["mean_absolute_error"])

# Train the model
lstm3.fit(X_train, y_train, epochs=50, batch_size=32)

#Model Prediction
y_pred = lstm3.predict(X_test)

mae = mean_absolute_error(y_test, y_pred)
print(f'Mean Absolute Error (MAE): {mae:.4f}')
# Out:
# Epoch 1/50
# 2/2 [==============================] - 3s 4ms/step - loss: 0.7379 - mean_absolute_error: 0.8391
# Epoch 2/50
# 2/2 [==============================] - 0s 5ms/step - loss: 0.7209 - mean_absolute_error: 0.8291
# Epoch 3/50
# 2/2 [==============================] - 0s 5ms/step - loss: 0.7041 - mean_absolute_error: 0.8193
# Epoch 4/50
# 2/2 [==============================] - 0s 6ms/step - loss: 0.6883 - mean_absolute_error: 0.8098
# Epoch 5/50
# 2/2 [==============================] - 0s 6ms/step - loss: 0.6722 - mean_absolute_error: 0.8002
# Epoch 6/50
# 2/2 [==============================] - 0s 5ms/step - loss: 0.6569 - mean_absolute_error: 0.7908
# Epoch 7/50
# 2/2 [==============================] - 0s 5ms/step - loss: 0.6423 - mean_absolute_error: 0.7815
# Epoch 8/50
# 2/2 [==============================] - 0s 4ms/step - loss: 0.6271 - mean_absolute_error: 0.7723
# Epoch 9/50
# 2/2 [==============================] - 0s 4ms/step - loss: 0.6130 - mean_absolute_error: 0.7632
# Epoch 10/50
# 2/2 [==============================] - 0s 4ms/step - loss: 0.5985 - mean_absolute_error: 0.7540
# Epoch 11/50
# 2/2 [==============================] - 0s 4ms/step - loss: 0.5846 - mean_absolute_error: 0.7449
# Epoch 12/50
# 2/2 [==============================] - 0s 5ms/step - loss: 0.5705 - mean_absolute_error: 0.7357
# Epoch 13/50
# 2/2 [==============================] - 0s 5ms/step - loss: 0.5570 - mean_absolute_error: 0.7266
# Epoch 14/50
# 2/2 [==============================] - 0s 5ms/step - loss: 0.5432 - mean_absolute_error: 0.7175
# Epoch 15/50
# 2/2 [==============================] - 0s 4ms/step - loss: 0.5299 - mean_absolute_error: 0.7084
# Epoch 16/50
# 2/2 [==============================] - 0s 4ms/step - loss: 0.5169 - mean_absolute_error: 0.6994
# Epoch 17/50
# 2/2 [==============================] - 0s 5ms/step - loss: 0.5038 - mean_absolute_error: 0.6902
# Epoch 18/50
# 2/2 [==============================] - 0s 8ms/step - loss: 0.4908 - mean_absolute_error: 0.6811
# Epoch 19/50
# 2/2 [==============================] - 0s 6ms/step - loss: 0.4785 - mean_absolute_error: 0.6721
# Epoch 20/50
# 2/2 [==============================] - 0s 6ms/step - loss: 0.4654 - mean_absolute_error: 0.6628
# Epoch 21/50
# 2/2 [==============================] - 0s 0s/step - loss: 0.4533 - mean_absolute_error: 0.6538
# Epoch 22/50
# 2/2 [==============================] - 0s 4ms/step - loss: 0.4412 - mean_absolute_error: 0.6447
# Epoch 23/50
# 2/2 [==============================] - 0s 0s/step - loss: 0.4290 - mean_absolute_error: 0.6355
# Epoch 24/50
# 2/2 [==============================] - 0s 4ms/step - loss: 0.4170 - mean_absolute_error: 0.6263
# Epoch 25/50
# 2/2 [==============================] - 0s 0s/step - loss: 0.4049 - mean_absolute_error: 0.6170
# Epoch 26/50
# 2/2 [==============================] - 0s 0s/step - loss: 0.3931 - mean_absolute_error: 0.6077
# Epoch 27/50
# 2/2 [==============================] - 0s 15ms/step - loss: 0.3811 - mean_absolute_error: 0.5981
# Epoch 28/50
# 2/2 [==============================] - 0s 4ms/step - loss: 0.3697 - mean_absolute_error: 0.5885
# Epoch 29/50
# 2/2 [==============================] - 0s 4ms/step - loss: 0.3572 - mean_absolute_error: 0.5785
# Epoch 30/50
# 2/2 [==============================] - 0s 3ms/step - loss: 0.3458 - mean_absolute_error: 0.5687
# Epoch 31/50
# 2/2 [==============================] - 0s 14ms/step - loss: 0.3339 - mean_absolute_error: 0.5586
# Epoch 32/50
# 2/2 [==============================] - 0s 10ms/step - loss: 0.3225 - mean_absolute_error: 0.5486
# Epoch 33/50
# 2/2 [==============================] - 0s 7ms/step - loss: 0.3108 - mean_absolute_error: 0.5383
# Epoch 34/50
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2993 - mean_absolute_error: 0.5280
# Epoch 35/50
# 2/2 [==============================] - 0s 0s/step - loss: 0.2881 - mean_absolute_error: 0.5176
# Epoch 36/50
# 2/2 [==============================] - 0s 6ms/step - loss: 0.2766 - mean_absolute_error: 0.5069
# Epoch 37/50
# 2/2 [==============================] - 0s 4ms/step - loss: 0.2656 - mean_absolute_error: 0.4962
# Epoch 38/50
# 2/2 [==============================] - 0s 4ms/step - loss: 0.2547 - mean_absolute_error: 0.4854
# Epoch 39/50
# 2/2 [==============================] - 0s 10ms/step - loss: 0.2435 - mean_absolute_error: 0.4744
# Epoch 40/50
# 2/2 [==============================] - 0s 4ms/step - loss: 0.2328 - mean_absolute_error: 0.4633
# Epoch 41/50
# 2/2 [==============================] - 0s 6ms/step - loss: 0.2219 - mean_absolute_error: 0.4520
# Epoch 42/50
# 2/2 [==============================] - 0s 6ms/step - loss: 0.2116 - mean_absolute_error: 0.4407
# Epoch 43/50
# 2/2 [==============================] - 0s 22ms/step - loss: 0.2012 - mean_absolute_error: 0.4292
# Epoch 44/50
# 2/2 [==============================] - 0s 10ms/step - loss: 0.1911 - mean_absolute_error: 0.4177
# Epoch 45/50
# 2/2 [==============================] - 0s 10ms/step - loss: 0.1810 - mean_absolute_error: 0.4060
# Epoch 46/50
# 2/2 [==============================] - 0s 9ms/step - loss: 0.1712 - mean_absolute_error: 0.3944
# Epoch 47/50
# 2/2 [==============================] - 0s 8ms/step - loss: 0.1619 - mean_absolute_error: 0.3827
# Epoch 48/50
# 2/2 [==============================] - 0s 14ms/step - loss: 0.1523 - mean_absolute_error: 0.3706
# Epoch 49/50
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1432 - mean_absolute_error: 0.3587
# Epoch 50/50
# 2/2 [==============================] - 0s 3ms/step - loss: 0.1344 - mean_absolute_error: 0.3466
# 1/1 [==============================] - 0s 296ms/step
# Mean Absolute Error (MAE): 0.1691

# %%
#Predicted vs True Adj Close Value LSTM
plt.plot(y_test, label='True Value')
plt.plot(y_pred, label='Model Value')
plt.title("Prediction by LSTM")
plt.xlabel('Time Scale')
plt.ylabel('Scaled Value')
plt.legend()
plt.show()

# %% [markdown]
# ### Analyze the results of each model. Record each MAE result in the format as below in your python notebook.
#
# ### Percobaan sesuai modul
#
# #### MAE of Model 1 - SimpleRNN
#  0.0850
#
# #### MAE of Model 2 - LSTM
#  0.3080
#
# #### MAE of Model 3 - - LSTM + Dropout ()
#  0.3203
#
# #### MAE of Model 4 - Bidirectional LSTM
#  0.3011

# %% [markdown]
# ### 14 Kesimpulan setelah mengulang
#
# Note that the MAE value is likely the same for each model. Why do you think that is? Additionally, try to re-run each model, noting whether the MAE values change. This possibility will happen every time you re-run. How did it happen? Look for references to support your answer, and put your answer in your python notebook.
#
# #### Answer:
# Sebenarnya ketiga jenis lstm berhasil MAE sama karena tadi variabel untuk memprediksi belum diganti menjadi masing", yaitu tadi hanya "model" untuk keempat algoritma. Model bidirectional LSTM kurang cocok  untuk memprediksi dataset saham. Ketika kita menjalankan ulang model, bobot seed diinisialisasi lagi, dan jika inisialisasi acak membuat model konvergen ke solusi yang sama, Anda mungkin akan melihat nilai MAE yang sama. Untuk mengatasi hal ini, kita dapat menetapkan seed untuk reprodusibilitas sebelum melatih model. Hal ini memastikan bahwa inisialisasi acak dari bobot adalah sama di seluruh proses yang berbeda.
